# %%
import habanero
from habanero import Crossref
from pprint import pprint
from collections import Counter # for easy counting
import ast # for string to dictionary conversion
import pandas as pd # for data manipulation
import numpy as np # for array manipulation

import urllib.request
from urllib.error import HTTPError

# %% [markdown]
# Inspiration: https://colab.research.google.com/github/EPS-Libraries-Berkeley/volt/blob/main/Search/crossref_library_module.ipynb#scrollTo=scyWPCPqcdP8

# %% [markdown]
# ## Get info from DOI

# %%
cr = Crossref() # create a crossref object

# %%
# query for the term "permafrost"
xai = cr.works(query = "xai")

# %%
dois= ['10.1016/j.artint.2021.103457','10.1109/MIS.2019.2957223','10.3390/e23081064']

# %%
dois=[
"arXiv:1806.09936",
"10.1007/978-3-030-10997-4_13",
"arXiv:1805.10820",
"10.1145/3236009",
"https://ercim-news.ercim.eu/images/stories/EN116/EN116-web.pdf#page=12",
"10.1007/978-3-030-16148-4_5",
"10.1007/978-3-030-24409-5_9",
"http://www.dpceonline.it/index.php/dpceonline/article/view/1083",
"10.1007/978-3-030-61527-7_24",
"http://ceur-ws.org/Vol-2646/18-paper.pdf",
"10.1016/j.artint.2020.103428",
"10.1109/ICDM50108.2020.00122",
"TBD - Submitted",
"10.1609/aaai.v33i01.33019780",
"10.1007/978-3-030-46150-8_12",
"10.1609/aaai.v34i09.7116",
"http://hdl.handle.net/11568/1088440",
"10.1145/3351095.3372855",
"10.1007/978-3-030-43823-4_14",
"10.1007/978-3-030-61527-7_27",
"10.1007/978-3-030-65965-3_34",
"10.1109/CogMI50398.2020.00029",
"10.1007/978-3-030-69128-8_2",
"no doi reference",
"no doi reference",
"10.1016/j.ipm.2021.102657",
"https://www.ildiabeteonline.it/intelligenza-artificiale-in-ambito-diabetologico-prospettive-dalla-ricerca-di-base-alle-applicazioni-cliniche/",
"10.1016/j.artint.2021.103457",
"10.1109/MIS.2019.2957223",
"10.3390/e23081064"
]

# %%
doi = '10.1007/978-3-030-10997-4_13'

paper=cr.works(ids = doi)
papero={}

if 'abstract' in paper['message']:
    papero['abstract']=paper['message']['abstract'].lstrip('<jats:p>').rstrip('</jats:p>')
papero['url']=paper['message']['URL']
papero['title']=paper['message']['title'][0]
papero['year']=paper['message']['indexed']['date-parts'][0][0] #non sono sicuro sia il modo corretto di prendere l'anno
papero['paperType']=paper['message']['type']
papero['container']=paper['message']['container-title'][0]
papero['publisher']=paper['message']['publisher']
papero['ISSN'] = paper['message']['ISSN'][0]
papero['authors']=''
authorList=paper['message']['author']
for i,author in enumerate(authorList):
    if i== len(authorList)-1:
        papero['authors'] += author['family'] + ' ' + author['given']
    else:
        papero['authors'] += author['family'] + ' ' + author['given'] + ', '
        

print(f"{papero['authors']} ({papero['year']}). {papero['title']} - {papero['paperType']}: {papero['container']}. ")
pprint(papero)
# print(year)
# Out:
# Guidotti Riccardo, Soldani Jacopo, Neri Davide, Brogi Antonio, Pedreschi Dino (2021). Helping Your Docker Images to Spread Based on Explainable Models - book-chapter: Machine Learning and Knowledge Discovery in Databases.
# {'ISSN': '0302-9743',
#  'authors': 'Guidotti Riccardo, Soldani Jacopo, Neri Davide, Brogi Antonio, '
#             'Pedreschi Dino',
#  'container': 'Machine Learning and Knowledge Discovery in Databases',
#  'paperType': 'book-chapter',
#  'publisher': 'Springer International Publishing',
#  'title': 'Helping Your Docker Images to Spread Based on Explainable Models',
#  'url': 'http://dx.doi.org/10.1007/978-3-030-10997-4_13',
#  'year': 2021}

# %%
papersExcel=[]
papersReference=[]

for i,doi in enumerate(dois):
    try:
        paper=cr.works(ids = doi)
        papero={}
        
        papero['title']=paper['message']['title'][0]
        if 'abstract' in paper['message']:
            papero['abstract']=paper['message']['abstract'].lstrip('<jats:p>').rstrip('</jats:p>')
        papero['DOI']=paper['message']['URL']
        papero['year']=paper['message']['indexed']['date-parts'][0][0] #non sono sicuro sia il modo corretto di prendere l'anno
        papero['paperType']=paper['message']['type']
        papero['container']=paper['message']['container-title'][0]
        papero['publisher']=paper['message']['publisher']
        papero['ISSN'] = paper['message']['ISSN'][0]
        papero['authors']=''
        authorList=paper['message']['author']
        papero['DOI_exists']='True'
        for i,author in enumerate(authorList):
            if i== len(authorList)-1:
                papero['authors'] += author['family'] + ' ' + author['given']
            else:
                papero['authors'] += author['family'] + ' ' + author['given'] + ', '
        papero['references-count']=paper['message']['references-count']

        reference=f"{papero['authors']} ({papero['year']}). {papero['title']} - {papero['paperType']}: {papero['container']}. "

        papersExcel.append(papero)
        papersReference.append(reference)
    except:
        print(f'DOI {doi} not found.')
        papero={}
        papero['DOI']=doi
        papero['DOI_exists']='False'
        papersExcel.append(papero)
        
# pprint(papersExcel)
# Out:
# DOI arXiv:1806.09936 not found.
# DOI arXiv:1805.10820 not found.
# DOI https://ercim-news.ercim.eu/images/stories/EN116/EN116-web.pdf#page=12 not found.
# DOI http://www.dpceonline.it/index.php/dpceonline/article/view/1083 not found.
# DOI http://ceur-ws.org/Vol-2646/18-paper.pdf not found.
# DOI 10.1109/ICDM50108.2020.00122 not found.
# DOI TBD - Submitted not found.
# DOI http://hdl.handle.net/11568/1088440 not found.
# DOI 10.1145/3351095.3372855 not found.
# DOI 10.1109/CogMI50398.2020.00029 not found.
# DOI no doi reference not found.
# DOI no doi reference not found.
# DOI https://www.ildiabeteonline.it/intelligenza-artificiale-in-ambito-diabetologico-prospettive-dalla-ricerca-di-base-alle-applicazioni-cliniche/ not found.

# %% [markdown]
# ### [TODO] Manage Archive

# %%
papersDF=pd.DataFrame(papersExcel)
papersDF.sort_values(by=['DOI_exists', 'year'])
# Out:
#                                                   DOI DOI_exists  \
# 0                                    arXiv:1806.09936      False
# 2                                    arXiv:1805.10820      False
# 4   https://ercim-news.ercim.eu/images/stories/EN1...      False
# 7   http://www.dpceonline.it/index.php/dpceonline/...      False
# 9            http://ceur-ws.org/Vol-2646/18-paper.pdf      False
# 11                       10.1109/ICDM50108.2020.00122      False
# 12                                    TBD - Submitted      False
# 16                http://hdl.handle.net/11568/1088440      False
# 17                            10.1145/3351095.3372855      False
# 21                      10.1109/CogMI50398.2020.00029      False
# 23                                   no doi reference      False
# 24                                   no doi reference      False
# 26  https://www.ildiabeteonline.it/intelligenza-ar...      False
# 1      http://dx.doi.org/10.1007/978-3-030-10997-4_13       True
# 5       http://dx.doi.org/10.1007/978-3-030-16148-4_5       True
# 6       http://dx.doi.org/10.1007/978-3-030-24409-5_9       True
# 8      http://dx.doi.org/10.1007/978-3-030-61527-7_24       True
# 10     http://dx.doi.org/10.1016/j.artint.2020.103428       True
# 13     http://dx.doi.org/10.1609/aaai.v33i01.33019780       True
# 14     http://dx.doi.org/10.1007/978-3-030-46150-8_12       True
# 15         http://dx.doi.org/10.1609/aaai.v34i09.7116       True
# 18     http://dx.doi.org/10.1007/978-3-030-43823-4_14       True
# 19     http://dx.doi.org/10.1007/978-3-030-61527-7_27       True
# 20     http://dx.doi.org/10.1007/978-3-030-65965-3_34       True
# 25        http://dx.doi.org/10.1016/j.ipm.2021.102657       True
# 27     http://dx.doi.org/10.1016/j.artint.2021.103457       True
# 28         http://dx.doi.org/10.1109/mis.2019.2957223       True
# 29                http://dx.doi.org/10.3390/e23081064       True
# 3                   http://dx.doi.org/10.1145/3236009       True
# 22      http://dx.doi.org/10.1007/978-3-030-69128-8_2       True
#
#                                                 title    year  \
# 0                                                 NaN     NaN
# 2                                                 NaN     NaN
# 4                                                 NaN     NaN
# 7                                                 NaN     NaN
# 9                                                 NaN     NaN
# 11                                                NaN     NaN
# 12                                                NaN     NaN
# 16                                                NaN     NaN
# 17                                                NaN     NaN
# 21                                                NaN     NaN
# 23                                                NaN     NaN
# 24                                                NaN     NaN
# 26                                                NaN     NaN
# 1   Helping Your Docker Images to Spread Based on ...  2021.0
# 5   Investigating Neighborhood Generation Methods ...  2021.0
# 6   Explaining Multi-label Black-Box Classifiers f...  2021.0
# 8   Explaining Sentiment Classification with Synth...  2021.0
# 10  Evaluating local explanation methods on ground...  2021.0
# 13  Meaningful Explanations of Black Box AI Decisi...  2021.0
# 14  Black Box Explanation by Learning Image Exempl...  2021.0
# 15  Explaining Image Classifiers Generating Exempl...  2021.0
# 18             Global Explanations with Local Scoring  2021.0
# 19  Predicting and Explaining Privacy Risk Exposur...  2021.0
# 20  Prediction and Explanation of Privacy Risk on ...  2021.0
# 25  FairLens: Auditing black-box clinical decision...  2021.0
# 27  GLocalX - From Local to Global Explanations of...  2021.0
# 28  Factual and Counterfactual Explanations for Bl...  2021.0
# 29  Occlusion-Based Explanations in Deep Recurrent...  2021.0
# 3   A Survey of Methods for Explaining Black Box M...  2022.0
# 22                                     Trustworthy AI  2022.0
#
#           paperType                                          container  \
# 0               NaN                                                NaN
# 2               NaN                                                NaN
# 4               NaN                                                NaN
# 7               NaN                                                NaN
# 9               NaN                                                NaN
# 11              NaN                                                NaN
# 12              NaN                                                NaN
# 16              NaN                                                NaN
# 17              NaN                                                NaN
# 21              NaN                                                NaN
# 23              NaN                                                NaN
# 24              NaN                                                NaN
# 26              NaN                                                NaN
# 1      book-chapter  Machine Learning and Knowledge Discovery in Da...
# 5      book-chapter    Advances in Knowledge Discovery and Data Mining
# 6      book-chapter                      Precision Health and Medicine
# 8      book-chapter                                  Discovery Science
# 10  journal-article                            Artificial Intelligence
# 13  journal-article  Proceedings of the AAAI Conference on Artifici...
# 14     book-chapter  Machine Learning and Knowledge Discovery in Da...
# 15  journal-article  Proceedings of the AAAI Conference on Artifici...
# 18     book-chapter  Machine Learning and Knowledge Discovery in Da...
# 19     book-chapter                                  Discovery Science
# 20     book-chapter                           ECML PKDD 2020 Workshops
# 25  journal-article                Information Processing & Management
# 27  journal-article                            Artificial Intelligence
# 28  journal-article                           IEEE Intelligent Systems
# 29  journal-article                                            Entropy
# 3   journal-article                              ACM Computing Surveys
# 22     book-chapter  Reflections on Artificial Intelligence for Hum...
#
#                                             publisher       ISSN  \
# 0                                                 NaN        NaN
# 2                                                 NaN        NaN
# 4                                                 NaN        NaN
# 7                                                 NaN        NaN
# 9                                                 NaN        NaN
# 11                                                NaN        NaN
# 12                                                NaN        NaN
# 16                                                NaN        NaN
# 17                                                NaN        NaN
# 21                                                NaN        NaN
# 23                                                NaN        NaN
# 24                                                NaN        NaN
# 26                                                NaN        NaN
# 1                   Springer International Publishing  0302-9743
# 5                   Springer International Publishing  0302-9743
# 6                   Springer International Publishing  1860-949X
# 8                   Springer International Publishing  0302-9743
# 10                                        Elsevier BV  0004-3702
# 13  Association for the Advancement of Artificial ...  2374-3468
# 14                  Springer International Publishing  0302-9743
# 15  Association for the Advancement of Artificial ...  2374-3468
# 18                  Springer International Publishing  1865-0929
# 19                  Springer International Publishing  0302-9743
# 20                  Springer International Publishing  1865-0929
# 25                                        Elsevier BV  0306-4573
# 27                                        Elsevier BV  0004-3702
# 28  Institute of Electrical and Electronics Engine...  1541-1672
# 29                                            MDPI AG  1099-4300
# 3           Association for Computing Machinery (ACM)  0360-0300
# 22                  Springer International Publishing  0302-9743
#
#                                               authors  references-count  \
# 0                                                 NaN               NaN
# 2                                                 NaN               NaN
# 4                                                 NaN               NaN
# 7                                                 NaN               NaN
# 9                                                 NaN               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 21                                                NaN               NaN
# 23                                                NaN               NaN
# 24                                                NaN               NaN
# 26                                                NaN               NaN
# 1   Guidotti Riccardo, Soldani Jacopo, Neri Davide...              37.0
# 5   Guidotti Riccardo, Monreale Anna, Cariaggi Leo...              32.0
# 6   Panigutti Cecilia, Guidotti Riccardo, Monreale...              26.0
# 8   Lampridis Orestis, Guidotti Riccardo, Ruggieri...              40.0
# 10                                  Guidotti Riccardo              48.0
# 13  Pedreschi Dino, Giannotti Fosca, Guidotti Ricc...               0.0
# 14  Guidotti Riccardo, Monreale Anna, Matwin Stan,...              33.0
# 15  Guidotti Riccardo, Monreale Anna, Matwin Stan,...               0.0
# 18  Setzu Mattia, Guidotti Riccardo, Monreale Anna...              27.0
# 19  Naretto Francesca, Pellungrini Roberto, Monrea...              29.0
# 20  Naretto Francesca, Pellungrini Roberto, Nardin...              27.0
# 25  Panigutti Cecilia, Perotti Alan, Panisson Andr...              98.0
# 27  Setzu Mattia, Guidotti Riccardo, Monreale Anna...              42.0
# 28  Guidotti Riccardo, Monreale Anna, Giannotti Fo...              10.0
# 29        Resta Michele, Monreale Anna, Bacciu Davide              42.0
# 3   Guidotti Riccardo, Monreale Anna, Ruggieri Sal...             142.0
# 22  Chatila Raja, Dignum Virginia, Fisher Michael,...              62.0
#
#                                              abstract
# 0                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 9                                                 NaN
# 11                                                NaN
# 12                                                NaN
# 16                                                NaN
# 17                                                NaN
# 21                                                NaN
# 23                                                NaN
# 24                                                NaN
# 26                                                NaN
# 1                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 8   itle>Abstract</jats:title>\n<jats:p>We present...
# 10                                                NaN
# 13  Black box AI systems for automated decision ma...
# 14                                                NaN
# 15  We present an approach to explain the decision...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 25                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  The biomedical field is characterized by an ev...
# 3   In recent years, many accurate decision suppor...
# 22                                                NaN

# %% [markdown]
# ## Doi to bibtex

# %%
BASE_URL = 'http://dx.doi.org/'
url = BASE_URL + doi
req = urllib.request.Request(url)
req.add_header('Accept', 'application/x-bibtex')
try:
    with urllib.request.urlopen(req) as f:
        bibtex = f.read().decode()
    print(bibtex)
except HTTPError as e:
    if e.code == 404:
        print('DOI not found.')
    else:
        print('Service unavailable.')
    sys.exit(1)

print(type(bibtex))
# Out:
# @article{Resta_2021,
# 	doi = {10.3390/e23081064},
# 	url = {https://doi.org/10.3390%2Fe23081064},
# 	year = 2021,
# 	month = {aug},
# 	publisher = {{MDPI} {AG}},
# 	volume = {23},
# 	number = {8},
# 	pages = {1064},
# 	author = {Michele Resta and Anna Monreale and Davide Bacciu},
# 	title = {Occlusion-Based Explanations in Deep Recurrent Models for Biomedical Signals},
# 	journal = {Entropy}
# }
# <class 'str'>

# %% [markdown]
# TROVARE IL DOI DI XAI

# %% [markdown]
# funder XAI = {'DOI': '10.13039/100010663',
#   'award': ['G.A. 834756'],
#   'doi-asserted-by': 'publisher',
#   'name': 'H2020 European Research Council'}

# %% [markdown]
# Check documentation for funders:
# https://habanero.readthedocs.io/en/latest/modules/crossref.html

# %% [markdown]
# ## Write Google Doc

# %% [markdown]
# Create a google DOC like this one
# https://docs.google.com/spreadsheets/d/1VaF5jAauYYYKo1WH40kLlsQ0-azIX5eMZoFYv5JrVr0/edit#gid=0

# %% [markdown]
# Check update function to write Google DOC

# %%
import pygsheets
